# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Exploratory Text Analytics | Spring 2024

# %% [markdown]
# # Metadata
#
# - Full Name: JiHo Lee
# - Userid: qxz6hb
# - GitHub Repo URL: https://github.com/jihoLee96/DS5001-2024-01-R/tree/main/final_project
# - UVA Box URL: https://virginia.box.com/s/c78wh9habdd4xkb0nmkkr3edoqy6anj5

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# [description]
#
# The source material I have chosen is the Harry Potter book series by J.K. Rowling. These bookse are widely known fantasy novel describing the journey of wizard, Harry Potter, and his friends Hermione and Ron. The story revovles around the school life in Hogwarts School of Witchcraft and Wizrdy and the battle story against dark wizard Voldemort.
#
# The Harry Potter series consists of following seven novels:
# 1. Harry Potter and the Sorcerer's Stone (1997)
# 2. Harry Potter and the Chamber of Secrets - (1998)
# 2. Harry Potter and the Prisoner of Azkaban (1999)
# 3. Harry Potter and the Goblet of Fire (2000)
# 4. Harry Potter and the Order of the Phoenix (2003)
# 5. Harry Potter and the Half-Blood Prince (2005)
# 6. Harry Potter and the Deathly Hallows (2007)
#
# I found the text file of the books in github repository([link](https://github.com/bobdeng/owlreader/tree/master/ERead/assets/books)).

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://github.com/bobdeng/owlreader/tree/master/ERead/assets/books
# - UVA Box URL: https://virginia.box.com/s/o5tkmjlzzhedhhsh40t7w0cvgegfnhe1
# - Number of raw documents: 7
# - Total size of raw documents (e.g. in MB): 6.18 MB
# - File format(s), e.g. XML, plaintext, etc.: plain text in .txt file

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# [description]
# 1. Harry Potter and the Sorcerer's Stone (1997)
# Title: The document starts with its title and following it with the contents of the book.
# Chapters: The book consists of chapters. The chapter's format is `CHAPTER ONE`, `CHAPTER TWO`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The document is a conversion of scanned book into text format, occasional page numbers are inserted in the text file from the actual book. The closing is `THE END`
#
# 2. Harry Potter and the Chamber of Secrets - (1998)
# Title: The document starts with its title and following it with the contents of the book.
# Author: The document contain its author of the book.
# Meta text: The extra text indicating the document is scanned, the date it is scanned, and version of the document.
# Chapters: The book consists of chapters. The chapter's format is `CHAPTER ONE`, `CHAPTER TWO`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The document is a conversion of scanned book into text format, occasional page numbers are inserted in the text file from the actual book. The closing is `THE END`
#
# 3. Harry Potter and the Prisoner of Azkaban (1999)
# Title: The document starts with its title and following it with the author and the contents of the book.
# Author: The document contain its author of the book.
# Chapters: The book consists of chapters. The chapter's format is `CHAPTER ONE`, `CHAPTER TWO`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The closing is `THE END`
#
# 4. Harry Potter and the Goblet of Fire (2000)
# Title: The document starts with its title and following it with the author and the contents of the book.
# Author: The document contain its author of the book.
# Chapters: The book consists of chapters. The chapter's format is `CHAPTER ONE`, `CHAPTER TWO`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The closing is `THE END` with text which is from the processor of the document.
#
# 5. Harry Potter and the Order of the Phoenix (2003)
# Title: The document starts with its title and following it with the contents of the book.
# Author: The document contain its author of the book.
# Chapters: The book consists of chapters. The chapter's format is `- CHAPTER ONE -`, `- CHAPTER TWO -`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The closing is `THE END`
#
# 6. Harry Potter and the Half-Blood Prince (2005))
# Title: The document starts with its title and following it with the contents of the book.
# Chapters: The book consists of chapters. The chapter's format is `Chapter 1:`, `Chpater 2:`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The closing is `THE END`
#
# 7. Harry Potter and the Deathly Hallows (2007)
# Title: The document starts with its title and following it with the contents of the book.
# Author: The document contain its author of the book.
# Chapters: The book consists of chapters. The chapter's format is `Chapter One`, `Chpater two`,... After the chapter index, it has title of the chapters.
# The chapters composed of paragraphs, and paragraphs consists of sentences. The closing is `THE END`

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.box.com/s/jjd7cjrj2cdxugljf8lg97tcoxjhsxp2
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Number of observations: 7 books
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.):
# book_id, source_file_path, raw_title, length of the book in characters, number of chapters, the regex expression for the chapter, author, and the length of the book in terms of the tokens
# - Average length of each document in characters:
# 905861

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
#
# - UVA Box URL: https://virginia.box.com/s/pjberfm6i3lnz8kwg4duahy9n4ayodoz
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter:`,`
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 1,101,190
# - OHCO Structure (as delimitted column names): [`book_id`, `chap_id`, `para_num`, `sent_num`, `token_num`]
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`):
# [`pos_tuple`, `pos`, `token_str`, `term_str`, `pos_group`]

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL: https://virginia.box.com/s/qoxqeytfr4z9l2l5q4h6vy7bz06cs7uv
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter:`,`
# - Number of observations: 23,202
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`):
# [`n`, `n_chars`, `p`, `i`, `cat_pos`, `max_pos`, `n_pos`, `max_pos_group`, `stop`, `dfidf`, `stem_porter`, `stem_snowball`, `stem_lancaster`]
#
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`.
# - List the top 20 significant words in the corpus by DFIDF.
#
# [list] \
# term_str \
# deal        100.840081 \
# notice      100.840081 \
# snarled     100.840081 \
# heavily     100.840081 \
# mention     100.840081 \
# easy        100.840081 \
# skin        100.840081 \
# distant     100.840081 \
# hanging     100.840081 \
# split       100.840081 \
# twice       100.840081 \
# eagerly     100.840081 \
# normal      100.840081 \
# forest      100.840081 \
# malfoys     100.840081 \
# softly      100.840081 \
# brightly    100.840081 \
# showing     100.840081 \
# lessons     100.840081 \
# shouldnt    100.831849 \

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL: https://virginia.box.com/s/fpuffq93k1ohzyp1j5yvi5jaupz3v0ki
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Bag (expressed in terms of OHCO levels): Chapter - `chap_id` : (`book_id`, `chap_id`)
# - Number of observations: 276,792
# - Columns (as delimitted names, including `n`, `tfidf`): `term_str`, `n`, `tf`, `tfidf`

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL: https://virginia.box.com/s/qh29na7vqjw9o3blzh2bgsoovufdyegv
# - UVA Box URL of BOW used to generate (if applicable): https://virginia.box.com/s/fpuffq93k1ohzyp1j5yvi5jaupz3v0ki
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Bag (expressed in terms of OHCO levels): Chapter - `chap_id` : (`book_id`, `chap_id`)

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/7us818pk0b1bjtvqa3eqao0mo7kv601d
# - UVA Box URL of DTM or BOW used to create:
# DTM:https://virginia.box.com/s/qh29na7vqjw9o3blzh2bgsoovufdyegv
# BOW:https://virginia.box.com/s/fpuffq93k1ohzyp1j5yvi5jaupz3v0ki
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Description of TFIDIF formula ($\LaTeX$ OK): \
#    The method used for calculating TFIDF is 'max' for TF, and 'standard' for IDF.
#    The calculation normalizes TF by dividing each term's frequency by the maximum frequency of any term in the document.
#    IDF is calculated by taking the logarithm of the total number of documents divided by the DF of each term.
#
#    DTCM = BOW.n.unstack() \
#    TF = (DTCM.T / DTCM.T.max()).T #max \
#    IDF = np.log2(N_docs/DF) #standard \
#    TFIDF = TF*IDF \
#    TFIDF = TFIDF.fillna(0)

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/gma2gfb1pgf29r59la5hous0xi3z6mtw
# - UVA Box URL of source TFIDF table: https://virginia.box.com/s/7us818pk0b1bjtvqa3eqao0mo7kv601d
# - GitHub URL for notebook used to create: <mark> LATER <mark>
# - Delimitter: `,`
# - Number of features (i.e. significant words): 1000
# - Principle of significant word selection: \
#     To select significant words, the criteria is DFIDF values. The POS list to filter only with no proper nouns is as below. The number of words is 1,000. \
#     vocab filter : dfidf  \
#     pos_list = NN NNS VB VBD VBG VBN VBP VBZ JJ JJR JJS RB RBR RBS".split() # Open categories with no proper nouns, group by book

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL: https://virginia.box.com/s/0vblwsondvfk1u64xjdpp2z1552wg1zp
# - UVA Box URL of the source TFIDF_L2 table:
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Number of components: 10
# - Library used to generate: Did not use library
# - Top 5 positive terms for first component: \
#     ter yeh o giant dragon \
#     dementors snake forest dog trunk	 \
#     master elf sir kitchen snake	\
#     forest sir team master trees	 \
#     broom team match broomstick dog
# - Top 5 negative terms for second component: \
#     sir kitchen snake elf bedroom \
#     sir elf class memory box \
#     class team lesson ball broom	 \
#     letter kitchen owl street bedroom	\
#     class towards potion lesson snake

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/1xa6iibmmhldqsmdtrqh45drr819252l
# - GitHub URL for notebook used to create: <mark> LATER <mark>
# - Delimitter: `,`

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL:https://virginia.box.com/s/86mjduhxpw17lt795dpeqy5opzd4a2aa
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![newplot.png](attachment:newplot.png)

# %% [markdown]
# ![newplot%20%281%29.png](attachment:newplot%20%281%29.png)
# Briefly describe the nature of the polarity you see in the first component:
#
# [description] \
# The metadat feature is the published year of each book. The polarity in the first component shows that the clustering or spread along x-axis indicate changes in document characteristics over the years. The loading scatterplot shows the clustered points towards the center and scattered points along the x-asis. This implied that the first component captures significant differences among the documents.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![newplot%20%282%29.png](attachment:newplot%20%282%29.png)

# %% [markdown]
# ![newplot%20%283%29.png](attachment:newplot%20%283%29.png)
# Briefly describe the nature of the polarity you see in the second component:
#
# [description] \
# Compared to the first component, by representation on PCA scatterplots, the polarity shows a less dominant. The scatterplot of documents does not display clear clustering by year. The loading plot shows less clustered trend compared to the first component. It suggests that no single variable dominates the component.

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL: https://virginia.box.com/s/aupm4c4emq969a3b8nq5i0rma3ie94z4
# - UVA Box URL of count matrix used to create:
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`
# - Libary used to compute: \
# from sklearn.feature_extraction.text import CountVectorizer \
# from sklearn.decomposition import LatentDirichletAllocation as LDA
# - A description of any filtering, e.g. POS (Nouns and Verbs only):\
#     The regex is used to choose singular noun and plural noun only. \
# pos_remove_pat=r'^NNS?$'
# - Number of components:\
# 20
# - Any other parameters used:\
# max_iter = 5 \
# n_features = 4000 \
# lda_n_top_terms = 7
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00: broom	match	field	team	crowd	goal	stands -> (label) broom match field team crowd goal stands
#   - T01: field	goblin	eyes	room	wizards	veela	time -> (label) field goblin eyes room wizards veela time
#   - T02: time	door	voice	eyes	face	hand	way	-> (label) time door voice eyes face hand way
#   - T03: time	hand	room	people	voice	yes	look -> (label) time hand room people voice yes look
#   - T04: room	time	car	face	memory	hand	house -> (label) room time car face memory hand house

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL: https://virginia.box.com/s/62ngtgqnp6ff4781mbvdtvqtt7onn7wr
# - GitHub URL for notebook used to create:<mark>LATER<mark>
# - Delimitter: `,`

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL:https://virginia.box.com/s/mstg8onvnps3z10gd76i4xf3r7hagryf
# - GitHub URL for notebook used to create:<mark>LATER<mark>
# - Delimitter:`,`

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the PHI table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL: https://virginia.box.com/s/20wltho9udjthn964q1pd2drbctojkxe
# - UVA Box URL for source lexicon: https://virginia.box.com/s/cjm1ub34vq5f37p0r4ttxiuq539zh852
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL:https://virginia.box.com/s/tm2huxa8xoqge8yrao3cw9h2wou4yaed
# - GitHub URL for notebook used to create: <mark>LATER<mark>
# - Delimitter: `,`

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL: https://virginia.box.com/s/bnb49ospyubt5tvr8fivzk5q182sdixb
# - GitHub URL for notebook used to create:<mark>LATER<mark>
# - Delimitter:`,`
# - Document bag expressed in terms of OHCO levels: Chapter - `chap_id` : (`book_id`, `chap_id`)

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# ![newplot%20%284%29.png](attachment:newplot%20%284%29.png)

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL: https://virginia.box.com/s/qwfqmo63lwoyc8092hmpzndbapijf07f
# - GitHub URL for notebook used to create:<mark>LATER<mark>
# - Delimitter: `,`
# - Document bag expressed in terms of OHCO levels: Chapter - `chap_id` : (`book_id`, `chap_id`)
# - Number of features generated: 1,770
# - The library used to generate the embeddings: \
#     from gensim.models import word2vec \
# from gensim.corpora import Dictionary \
# from sklearn.manifold import TSNE as tsne \
# import gensim

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
# ![newplot%20%285%29.png](attachment:newplot%20%285%29.png)

# %% [markdown]
# ![newplot%20%286%29.png](attachment:newplot%20%286%29.png)
#
# This cluster have words related to body part such as eyes, kneew, hands, and glasses. It was interesting that the word cluster has wand in it because Harry Potter is a book related to magic. Also, it has word cloack which might related to their clothing style of wizards.

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
#
# ![newplot%20%288%29.png](attachment:newplot%20%288%29.png)
#
# The HAC graph visually represents how different words from the books are grouped together based on their similarity, forming hierarchical clusters. \
# The red lined cluster consists of words such as shop, page, names, escape, carry, learn, finding, and support. These words might related to activities or events involving learning, finding information. This makes sense as the novels scene is usually around the Hogward School. This possibly reflects the scenes where characters are engaged in educational contexts. \
# The green lined cluster consists of words such as finished, seen, wore, dress, overhead, dust, horror, speed, ... These words could be connected to illustation of physical movement or appearances. There are scenes related to fast-paced acitions or emotional situations. We can assume that the novels often describes scenes fight back with monsters, and dark magicians, and the scenes where they are escaped, run away from something. \
# The last orange lined cluster seemes to related to conversational or emotinal expressions. These can be captured by dialogue or monologues in the novels. The novels have a large volume of dialoges among the characters reflecting the communicative and emotional aspects of the narrative.

# %% [markdown]
# ## Riff 2 (5)
#
# ![newplot%20%289%29.png](attachment:newplot%20%289%29.png)

# %% [markdown]
# ![newplot%20%2810%29.png](attachment:newplot%20%2810%29.png)
#
# These dispersion plots show the first and last vooks of the Harry Potter series, respectively. We can observe that the word dress frequently appears in the early series due to frequent mentions of school uniforms for the admission. But, it rarely appears in the final book. Additionally, word such as dark, horror, whispered, and escape are prevalent throughout the series. However, the word dark appears less frequent in the last book, meaning that the dark atmosphere resolves in the final sereis. The story of the last Harry Potter centers on the final battle with Voldemort. In the middle, the story is about Harry realizing he is a kind of Horcrux linked to Voldemort and ultimately leads to a peaceful and family-oriented ending.

# %% [markdown]
# ## Riff 3 (5)
#
# ![newplot%20%2811%29.png](attachment:newplot%20%2811%29.png)

# %% [markdown]
# ![newplot%20%2812%29.png](attachment:newplot%20%2812%29.png)
#
# These graphs illustrate the the words horror and dark in the first and last books of the Harry Potter series. In the first graph, horror is represented in blue and dark in orange line, while in the last graph, the colors are opposite with dark in blue and horror in orange. In the first series book, the word horror is dominantly used early on as Harry faces bullying at aunt's home and surprise at the magical world. As the story progresses, the atmosphere darkens, especially when the main characters searching for the Philosopher's Stone to fight aginst Voldemort. In the last book, a dark atmosphere is general from the beginning to the end, with a noticeable decrease towards the finale. In both books, the frequency of these words decreases as conflicts are resolved and the narrative concludes.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
